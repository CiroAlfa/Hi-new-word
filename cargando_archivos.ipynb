# %% [markdown]
# <a href="https://colab.research.google.com/github/CiroAlfa/Hi-new-world/blob/main/cargando_archivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv')
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# #si el separador no es una , sino un|haríamos:

# %%
pd.read_csv('/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv', sep='|')
# Out:
#       Name,Author,User Rating,Reviews,Price,Year,Genre
# 0    10-Day Green Smoothie Cleanse,JJ Smith,4.7,173...
# 1    11/22/63: A Novel,Stephen King,4.6,2052,22,201...
# 2    12 Rules for Life: An Antidote to Chaos,Jordan...
# 3    1984 (Signet Classics),George Orwell,4.7,21424...
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545  Wrecking Ball (Diary of a Wimpy Kid Book 14),J...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
# [550 rows x 1 columns]

# %%
pd.read_csv('/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv', header=2)
# Out:
#                                      11/22/63: A Novel  \
# 0              12 Rules for Life: An Antidote to Chaos
# 1                               1984 (Signet Classics)
# 2    5,000 Awesome Facts (About Everything!) (Natio...
# 3        A Dance with Dragons (A Song of Ice and Fire)
# 4    A Game of Thrones / A Clash of Kings / A Storm...
# ..                                                 ...
# 543       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 544  You Are a Badass: How to Stop Doubting Your Gr...
# 545  You Are a Badass: How to Stop Doubting Your Gr...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
#
#                  Stephen King  4.6   2052  22  2011      Fiction
# 0          Jordan B. Peterson  4.7  18979  15  2018  Non Fiction
# 1               George Orwell  4.7  21424   6  2017      Fiction
# 2    National Geographic Kids  4.8   7665  12  2019  Non Fiction
# ...

# %%
df_books =pd.read_csv('/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv',header=0)
df_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df_books.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
df_books =pd.read_csv('/content/bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv',header=0,names=['Namesss', 'Authorrrr', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')
df_books
# Out:
#                                                Namesss  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                     Authorrrr User Rating Reviews Price  Year        Genre
# 0                    JJ Smith         4.7   17350     8  2016  Non Fiction
# 1                Stephen King         4.6    2052    22  2011      Fiction
# 2          Jordan B. Peterson         4.7   18979    15  2018  Non Fiction
# ...
